# %% [markdown]
# # Neural Network

# %% [markdown]
# ## Understanding Artificial Neural Networks Theory

# %% [markdown]
# #### En el notebook anterior he utilizado la tecnica de regresion lineal, la cual es muy util, pero presenta el problema de que se supone que hay una relacion lineal entre las variables a estudiar
#
# #### En este caso voy a utilizar redes neuronales, que se comportan bastante bien tanto cuando hay relaciones lineales como cuando no
#
# [Informacion sobre las Redes Neuronales Artificiales](https://es.wikipedia.org/wiki/Red_neuronal_artificial)

# %% [markdown]
# ## TensorFlow's High Level Estimator API

# %% [markdown]
# #### [TensorFlow](https://es.wikipedia.org/wiki/TensorFlow) es una biblioteca de código abierto para aprendizaje automático a través de un rango de tareas, y desarrollado por Google para satisfacer sus necesidades de sistemas capaces de construir y entrenar redes neuronales para detectar y descifrar patrones y correlaciones, análogos al aprendizaje y razonamiento usados por los humanos.

# %% [markdown]
# ## Construyendo un DNNRegressor para predecir el clima

# %% [markdown]
# #### En este notebook voy a describir como usar uno de los estimadores mas potentes de redes neuronales, el [DNN Regressor](https://www.tensorflow.org/api_docs/python/tf/estimator/DNNRegressor)

# %% [markdown]
# #### Importo las librerias que voy a usar

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.metrics import explained_variance_score, mean_absolute_error, median_absolute_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Abro el DF exportado de la segunda parte

# %%
import pickle
with open('end-part2_df.pkl', 'rb') as fp:
    df = pickle.load(fp)

# %%
# Muestro el DF
df.describe().T
# Out:
#         count       mean       std  min     25%    50%    75%   max
# tmed    912.0  14.646162  7.740936  0.5   8.375  12.60  21.05  32.5
# tmed_1  912.0  14.649123  7.730972  0.5   8.400  12.60  21.05  32.5
# tmed_2  912.0  14.642215  7.727721  0.5   8.400  12.60  21.05  32.5
# tmed_3  912.0  14.637829  7.722571  0.5   8.375  12.60  21.05  32.5
# tmin_1  912.0   8.295504  6.952217 -5.4   2.675   7.60  13.80  24.5
# tmin_2  912.0   8.293860  6.950907 -5.4   2.700   7.60  13.80  24.5
# tmin_3  912.0   8.294079  6.949257 -5.4   2.700   7.60  13.80  24.5
# tmax_1  912.0  21.004276  9.060720  2.6  13.500  18.95  28.85  42.2
# tmax_2  912.0  20.991776  9.056666  2.6  13.500  18.95  28.85  42.2
# tmax_3  912.0  20.983114  9.050151  2.6  13.500  18.95  28.85  42.2

# %%
# Veo mas informacion sobre el, para tener una idea clara de como era
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 912 entries, 2018-01-04 to 2020-12-31
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tmed    912 non-null    float64
#  1   tmed_1  912 non-null    float64
#  2   tmed_2  912 non-null    float64
#  3   tmed_3  912 non-null    float64
#  4   tmin_1  912 non-null    float64
#  5   tmin_2  912 non-null    float64
#  6   tmin_3  912 non-null    float64
#  7   tmax_1  912 non-null    float64
#  8   tmax_2  912 non-null    float64
#  9   tmax_3  912 non-null    float64
# dtypes: float64(10)
# memory usage: 78.4+ KB

# %% [markdown]
# #### Se puede observar que hay menos de 1000 filas de datos, todos son de caracter numerico y ademas no hay datos nulos o que falten. Esto se debe al preprocesado hecho en el primer notebook

# %% [markdown]
# #### Separo los atributos predictores del atributo que buscamos predecir

# %%
#X sera un dataframe de pandas con todas las columnas excepto la de tmed
X = df[[col for col in df.columns if col != 'tmed']]

# y sera una serie de pandas de el atributo tmed
y = df['tmed']

# %% [markdown]
# #### Como en todas las aplicaciones supervisadas de machine learning, voy a dividir el dataset en varios, uno para training y otro para testing
#
# #### Ademas, para explicar mejor el proceso iterativo de entrenar esta red neuronal, voy a usar un dataset adicional que sera para validacion
#
# #### Para el entrenamiento voy a utilizar el 80% de la informacion y para testear y validar usare el 10% restante para cada dataset

# %%
# Separo los datos en un dataset para training y otro dataset temporal mediante sklearn.model_selection.traing_test_split
X_train, X_tmp, y_train, y_tmp = train_test_split(X, y, test_size=0.2, random_state=23)

# %%
# Cojo el restante 20% de los datos, que esta en X_temp y y_temp y los separo equitativamente
X_test, X_val, y_test, y_val = train_test_split(X_tmp, y_tmp, test_size=0.5, random_state=23)

X_train.shape, X_test.shape, X_val.shape
print("Instancias de entrenamiento   {}, Caracteristicas de entrenamiento   {}".format(X_train.shape[0], X_train.shape[1]))
print("Instancias de validacion {}, Caracteristicas de validacion  {}".format(X_val.shape[0], X_val.shape[1]))
print("Instancias de testing    {}, Carcateristicas de testing    {}".format(X_test.shape[0], X_test.shape[1]))
# Out:
# Instancias de entrenamiento   729, Caracteristicas de entrenamiento   9
# Instancias de validacion 92, Caracteristicas de validacion  9
# Instancias de testing    91, Carcateristicas de testing    9

# %% [markdown]
# ### Procedo a construir el DNN Regressor
# #### El primer paso a dar cuando se construlle una red neuronal es instanciar la clase `tf.estimator.DNNRegressor(...)`.
# #### El constructor de esta clase tiene muchos parametros pero yo me voy a fijar solo en los siguientes:
# - `feature_columns`: Una lista muy parecida a una estructura que contiene la definicion del nombre y los tipos de datos que van a alimentar el modelo
# - `hidden_units`: Una lista muy parecida a una estructura que contiene la definicion del numero de ancho y profundiad de la red neuronal
# - `optimizer`: Es una instanica de la subclase `tf.Optimizer`, que optimiza los pesos del modelo durante el entrenamiento. Por defecto es el optimizador AdaGrad
# - `activation_fn`: Una funcion de activacion que se usa para introducir no linealidad en la red en cada capa. Por defecto es [ReLu](https://en.wikipedia.org/wiki/Rectifier_(neural_networks))
# - `model_dir`: El directorio que se creara y contendra toda la metada y los puntos de control del modelo

# %% [markdown]
# #### Comienzo definiendo la lista de las columnas numericas relevantes.
# #### Para hacer esto uso la funcion `tf.feature_column.numeric_column()` que me devuelve una instancia de `FeatureColumn`

# %%
feature_cols = [tf.feature_column.numeric_column(col) for col in X.columns]

# %% [markdown]
# #### Ahora que ya tengo las columnas definidas, puedo instanciar la clase `DNNRegressor` y guardarla en la variable regresora.
# #### Especifico que quiero una red neuronal con dos capas profundas donde ambas capas tendran una anchura de 50 nodos.
# #### Tambien indico que la informacion de mi modelo se guarde en un directorio llamado tf_wk_model

# %%
regressor = tf.estimator.DNNRegressor(feature_columns=feature_cols,
                                      hidden_units=[50, 50],
                                      model_dir='tf_wx_model')
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'tf_wx_model', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# #### Lo siguiente cosa que quiero es definir una funcion reusable, que la llamare `wx_input_fn(...)`. Esta funcion sera usada para alimentar de datos mi red neuronal durante las fases de training y testing.
#
# #### Hay muchas maneras de construir input functions, pero yo describire como definir y usar una basada en `tf.estimator.inputs.pandas_input_fn(...)` ya que mi informacion se encuentra en una estructura de datos panda

# %%
def wx_input_fn(X, y=None, num_epochs=None, shuffle=True, batch_size=400):
    return tf.compat.v1.estimator.inputs.pandas_input_fn(x=X, 
                                                         y=y, 
                                                         batch_size=batch_size, 
                                                         num_epochs=num_epochs, 
                                                         shuffle=shuffle)

# %% [markdown]
# #### Se puede observar que la funcion `wx_input_fn(...)` toma un parametro obligatorio y 3 opcionales que los eligira tensorflow especificamente para los datos panda en la funcion que es retornada. Esta es una de las potentes caracteristicas del API de TensorFlow

# %% [markdown]
# #### Los parametros de la funcion se definen de la siguiente manera:
# - `X` : Las caracteristicas de entrada que alimentaran uno de los 3 metodos de mi `DNNRegressor`, (`train`, `evaluate` y `predict`)
# - `y` : Los valores objetivo de `X` que son opcionales y no seran proporcionados a la llamada de `predict`
# - `num_epochs` : Parametro opcional que sirve para especificar el numero de epocas. Una epoca ocurre cuando el algoritmo se ejecuta sobre todo el dataset una vez
# - `shuffle` : Parametro opcional, que especifica si seleccionar de forma random una pequeña parte del dataset cada vez que el algoritmo se ejecuta
# - `batch_size` : El numero de ejemplos a incluir cada vez que el algoritmo se ejecuta
#
# #### Ahora que ya tengo la funcion definida, procedo a entrenar la red neuronal

# %% [markdown]
# #### Defino un simple bucle de entrenamiento para entrenar el modelo con la training data y evaluarlo periodicamente con la evaluation data

# %% [markdown]
# #### El bucle siguiente itera 100 veces. En el cuerpo del bucle llamo al metodo del objeto regresor `train(...)`, pasandole mi funcion reusable `wx_input_fn(...)`.
# #### He dejado adrede el `num_epochs` a None, que quiere decir que no me importa el numero de veces que pase sobre el set de entrenamiento, solamente quiero que se mantenga el algoritmo de entrenamiento con un `batch_size` de 400, que es mas o menos la mitad del dataset.
# #### Tambien dejo el valor por defecto del parametro `shuffle`, es decir a `True` lo que significa que durante el entrenamiento, la data es seleccionada de forma aleatoria para evitar relaciones secuenciales.
# #### El ultimo parametro, `steps`, que vale 400, significa que el training set va a ser procesado 400 veces por iteracion

# %%
evaluations = []
STEPS = 400
for i in range(100):
    print(i)
    regressor.train(input_fn=wx_input_fn(X_train, y=y_train), steps=STEPS)
    evaluations.append(regressor.evaluate(input_fn=wx_input_fn(X_val,
                                                               y_val,
                                                               num_epochs=1,
                                                               shuffle=False)))
# Out:
# 0
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/lazy_loader.py:63: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/training_util.py:235: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.8/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:60: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.8/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:491: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/optimizer_v2/adagrad.py:82: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/monitored_session.py:906: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 308.91602, step = 0
# INFO:tensorflow:global_step/sec: 315.065
# INFO:tensorflow:loss = 8.003623, step = 100 (0.318 sec)
# INFO:tensorflow:global_step/sec: 366.271
# INFO:tensorflow:loss = 6.7993693, step = 200 (0.273 sec)
# INFO:tensorflow:global_step/sec: 359.04
# INFO:tensorflow:loss = 6.4878554, step = 300 (0.279 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 400...
# INFO:tensorflow:Saving checkpoints for 400 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 400...
# INFO:tensorflow:Loss for final step: 6.0346203.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:14:50Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.18375s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:14:50
# INFO:tensorflow:Saving dict for global step 400: average_loss = 6.4866805, global_step = 400, label/mean = 14.728261, loss = 6.4866805, prediction/mean = 15.039757
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 400: tf_wx_model/model.ckpt-400
# 1
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-400
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/saver.py:1076: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 400...
# INFO:tensorflow:Saving checkpoints for 400 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 400...
# INFO:tensorflow:loss = 6.0646605, step = 400
# INFO:tensorflow:global_step/sec: 316.986
# INFO:tensorflow:loss = 6.090801, step = 500 (0.317 sec)
# INFO:tensorflow:global_step/sec: 367.626
# INFO:tensorflow:loss = 5.981214, step = 600 (0.272 sec)
# INFO:tensorflow:global_step/sec: 360.948
# INFO:tensorflow:loss = 5.8337073, step = 700 (0.277 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 800...
# INFO:tensorflow:Saving checkpoints for 800 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 800...
# INFO:tensorflow:Loss for final step: 5.178929.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:14:52Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.16671s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:14:52
# INFO:tensorflow:Saving dict for global step 800: average_loss = 5.6406126, global_step = 800, label/mean = 14.728261, loss = 5.6406126, prediction/mean = 15.031919
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 800: tf_wx_model/model.ckpt-800
# 2
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 800...
# INFO:tensorflow:Saving checkpoints for 800 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 800...
# INFO:tensorflow:loss = 5.494596, step = 800
# INFO:tensorflow:global_step/sec: 315.845
# INFO:tensorflow:loss = 4.8676853, step = 900 (0.319 sec)
# INFO:tensorflow:global_step/sec: 368.725
# INFO:tensorflow:loss = 5.139342, step = 1000 (0.271 sec)
# INFO:tensorflow:global_step/sec: 366.17
# INFO:tensorflow:loss = 4.8100753, step = 1100 (0.273 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1200...
# INFO:tensorflow:Saving checkpoints for 1200 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1200...
# INFO:tensorflow:Loss for final step: 4.992984.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:14:54Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-1200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.18319s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:14:54
# INFO:tensorflow:Saving dict for global step 1200: average_loss = 5.1314683, global_step = 1200, label/mean = 14.728261, loss = 5.1314683, prediction/mean = 15.044291
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1200: tf_wx_model/model.ckpt-1200
# 3
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-1200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1200...
# INFO:tensorflow:Saving checkpoints for 1200 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1200...
# INFO:tensorflow:loss = 5.2742524, step = 1200
# INFO:tensorflow:global_step/sec: 315.458
# INFO:tensorflow:loss = 4.4798036, step = 1300 (0.318 sec)
# INFO:tensorflow:global_step/sec: 351.742
# INFO:tensorflow:loss = 4.6653876, step = 1400 (0.285 sec)
# INFO:tensorflow:global_step/sec: 364.525
# INFO:tensorflow:loss = 4.145863, step = 1500 (0.274 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1600...
# INFO:tensorflow:Saving checkpoints for 1600 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1600...
# INFO:tensorflow:Loss for final step: 4.352568.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:14:56Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-1600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.18821s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:14:57
# INFO:tensorflow:Saving dict for global step 1600: average_loss = 4.765268, global_step = 1600, label/mean = 14.728261, loss = 4.765268, prediction/mean = 15.0334
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1600: tf_wx_model/model.ckpt-1600
# 4
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-1600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1600...
# INFO:tensorflow:Saving checkpoints for 1600 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1600...
# INFO:tensorflow:loss = 4.762798, step = 1600
# INFO:tensorflow:global_step/sec: 312.231
# INFO:tensorflow:loss = 4.3568187, step = 1700 (0.322 sec)
# INFO:tensorflow:global_step/sec: 364.457
# INFO:tensorflow:loss = 4.11072, step = 1800 (0.274 sec)
# INFO:tensorflow:global_step/sec: 363.155
# INFO:tensorflow:loss = 4.1798744, step = 1900 (0.275 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2000...
# INFO:tensorflow:Saving checkpoints for 2000 into tf_wx_model/model.ckpt.
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/saver.py:968: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2000...
# INFO:tensorflow:Loss for final step: 4.2356725.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:14:59Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.18328s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:14:59
# INFO:tensorflow:Saving dict for global step 2000: average_loss = 4.5183134, global_step = 2000, label/mean = 14.728261, loss = 4.5183134, prediction/mean = 15.033692
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: tf_wx_model/model.ckpt-2000
# 5
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2000...
# INFO:tensorflow:Saving checkpoints for 2000 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2000...
# INFO:tensorflow:loss = 4.5367794, step = 2000
# INFO:tensorflow:global_step/sec: 291.783
# INFO:tensorflow:loss = 4.263083, step = 2100 (0.344 sec)
# INFO:tensorflow:global_step/sec: 321.309
# INFO:tensorflow:loss = 4.0312786, step = 2200 (0.311 sec)
# INFO:tensorflow:global_step/sec: 359.056
# INFO:tensorflow:loss = 4.200079, step = 2300 (0.278 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2400...
# INFO:tensorflow:Saving checkpoints for 2400 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2400...
# INFO:tensorflow:Loss for final step: 4.1204348.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:15:01Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-2400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.18252s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:15:01
# INFO:tensorflow:Saving dict for global step 2400: average_loss = 4.3557134, global_step = 2400, label/mean = 14.728261, loss = 4.3557134, prediction/mean = 15.01667
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2400: tf_wx_model/model.ckpt-2400
# 6
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-2400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2400...
# INFO:tensorflow:Saving checkpoints for 2400 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2400...
# INFO:tensorflow:loss = 3.7772443, step = 2400
# INFO:tensorflow:global_step/sec: 319.178
# INFO:tensorflow:loss = 4.142093, step = 2500 (0.315 sec)
# INFO:tensorflow:global_step/sec: 313.272
# INFO:tensorflow:loss = 4.3846116, step = 2600 (0.319 sec)
# INFO:tensorflow:global_step/sec: 355.543
# INFO:tensorflow:loss = 3.775078, step = 2700 (0.281 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2800...
# INFO:tensorflow:Saving checkpoints for 2800 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2800...
# INFO:tensorflow:Loss for final step: 4.2843614.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:15:03Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-2800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.19206s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:15:03
# INFO:tensorflow:Saving dict for global step 2800: average_loss = 4.243314, global_step = 2800, label/mean = 14.728261, loss = 4.243314, prediction/mean = 15.009871
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2800: tf_wx_model/model.ckpt-2800
# 7
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-2800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2800...
# INFO:tensorflow:Saving checkpoints for 2800 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2800...
# INFO:tensorflow:loss = 3.7763941, step = 2800
# INFO:tensorflow:global_step/sec: 310.765
# INFO:tensorflow:loss = 4.3480964, step = 2900 (0.323 sec)
# INFO:tensorflow:global_step/sec: 360.131
# INFO:tensorflow:loss = 3.6248682, step = 3000 (0.278 sec)
# INFO:tensorflow:global_step/sec: 358.814
# INFO:tensorflow:loss = 4.34083, step = 3100 (0.279 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3200...
# INFO:tensorflow:Saving checkpoints for 3200 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3200...
# INFO:tensorflow:Loss for final step: 3.8332512.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:15:06Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-3200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.18966s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:15:06
# INFO:tensorflow:Saving dict for global step 3200: average_loss = 4.1677547, global_step = 3200, label/mean = 14.728261, loss = 4.1677547, prediction/mean = 14.995654
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3200: tf_wx_model/model.ckpt-3200
# 8
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-3200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3200...
# INFO:tensorflow:Saving checkpoints for 3200 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3200...
# INFO:tensorflow:loss = 4.4824305, step = 3200
# INFO:tensorflow:global_step/sec: 288.006
# INFO:tensorflow:loss = 3.9352703, step = 3300 (0.349 sec)
# INFO:tensorflow:global_step/sec: 354.82
# INFO:tensorflow:loss = 4.1628265, step = 3400 (0.282 sec)
# INFO:tensorflow:global_step/sec: 362.753
# INFO:tensorflow:loss = 3.8598373, step = 3500 (0.275 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3600...
# INFO:tensorflow:Saving checkpoints for 3600 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3600...
# INFO:tensorflow:Loss for final step: 3.9892514.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:15:08Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-3600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.18656s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:15:08
# INFO:tensorflow:Saving dict for global step 3600: average_loss = 4.112036, global_step = 3600, label/mean = 14.728261, loss = 4.112036, prediction/mean = 14.988355
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3600: tf_wx_model/model.ckpt-3600
# 9
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-3600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3600...
# INFO:tensorflow:Saving checkpoints for 3600 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3600...
# INFO:tensorflow:loss = 4.22462, step = 3600
# INFO:tensorflow:global_step/sec: 335.631
# INFO:tensorflow:loss = 3.423995, step = 3700 (0.299 sec)
# INFO:tensorflow:global_step/sec: 354.591
# INFO:tensorflow:loss = 4.025523, step = 3800 (0.282 sec)
# INFO:tensorflow:global_step/sec: 366.635
# INFO:tensorflow:loss = 3.5791628, step = 3900 (0.273 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4000...
# INFO:tensorflow:Saving checkpoints for 4000 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4000...
# INFO:tensorflow:Loss for final step: 4.061178.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:15:10Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-4000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.19152s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:15:10
# INFO:tensorflow:Saving dict for global step 4000: average_loss = 4.081308, global_step = 4000, label/mean = 14.728261, loss = 4.081308, prediction/mean = 14.988562
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4000: tf_wx_model/model.ckpt-4000
# 10
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-4000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4000...
# INFO:tensorflow:Saving checkpoints for 4000 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4000...
# INFO:tensorflow:loss = 3.5260072, step = 4000
# INFO:tensorflow:global_step/sec: 334.428
# INFO:tensorflow:loss = 4.3550034, step = 4100 (0.301 sec)
# INFO:tensorflow:global_step/sec: 371.945
# INFO:tensorflow:loss = 3.72799, step = 4200 (0.269 sec)
# INFO:tensorflow:global_step/sec: 360.689
# INFO:tensorflow:loss = 3.6185224, step = 4300 (0.277 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4400...
# INFO:tensorflow:Saving checkpoints for 4400 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4400...
# INFO:tensorflow:Loss for final step: 4.156146.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:15:12Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-4400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.19013s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:15:12
# INFO:tensorflow:Saving dict for global step 4400: average_loss = 4.0613084, global_step = 4400, label/mean = 14.728261, loss = 4.0613084, prediction/mean = 14.9857855
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4400: tf_wx_model/model.ckpt-4400
# 11
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-4400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4400...
# INFO:tensorflow:Saving checkpoints for 4400 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4400...
# INFO:tensorflow:loss = 3.9532747, step = 4400
# INFO:tensorflow:global_step/sec: 326.734
# INFO:tensorflow:loss = 3.9061031, step = 4500 (0.307 sec)
# INFO:tensorflow:global_step/sec: 323.377
# INFO:tensorflow:loss = 3.8763752, step = 4600 (0.309 sec)
# INFO:tensorflow:global_step/sec: 349.182
# INFO:tensorflow:loss = 4.0377135, step = 4700 (0.286 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4800...
# INFO:tensorflow:Saving checkpoints for 4800 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4800...
# INFO:tensorflow:Loss for final step: 3.8987958.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:15:14Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-4800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.18331s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:15:15
# INFO:tensorflow:Saving dict for global step 4800: average_loss = 4.0526266, global_step = 4800, label/mean = 14.728261, loss = 4.0526266, prediction/mean = 14.988455
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4800: tf_wx_model/model.ckpt-4800
# 12
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-4800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4800...
# INFO:tensorflow:Saving checkpoints for 4800 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4800...
# INFO:tensorflow:loss = 3.726231, step = 4800
# INFO:tensorflow:global_step/sec: 324.305
# INFO:tensorflow:loss = 3.6087818, step = 4900 (0.310 sec)
# INFO:tensorflow:global_step/sec: 357.222
# INFO:tensorflow:loss = 3.7893395, step = 5000 (0.280 sec)
# INFO:tensorflow:global_step/sec: 350.128
# INFO:tensorflow:loss = 3.4416473, step = 5100 (0.286 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5200...
# INFO:tensorflow:Saving checkpoints for 5200 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5200...
# INFO:tensorflow:Loss for final step: 3.4605613.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:15:17Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-5200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.18236s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:15:17
# INFO:tensorflow:Saving dict for global step 5200: average_loss = 4.0457215, global_step = 5200, label/mean = 14.728261, loss = 4.0457215, prediction/mean = 14.9852915
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5200: tf_wx_model/model.ckpt-5200
# 13
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-5200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5200...
# INFO:tensorflow:Saving checkpoints for 5200 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5200...
# INFO:tensorflow:loss = 3.7304077, step = 5200
# INFO:tensorflow:global_step/sec: 327.963
# INFO:tensorflow:loss = 3.807721, step = 5300 (0.306 sec)
# INFO:tensorflow:global_step/sec: 357.475
# INFO:tensorflow:loss = 3.8627715, step = 5400 (0.280 sec)
# INFO:tensorflow:global_step/sec: 350.941
# INFO:tensorflow:loss = 3.92935, step = 5500 (0.285 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5600...
# INFO:tensorflow:Saving checkpoints for 5600 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5600...
# INFO:tensorflow:Loss for final step: 4.0382833.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:15:19Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-5600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.18136s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:15:19
# INFO:tensorflow:Saving dict for global step 5600: average_loss = 4.03967, global_step = 5600, label/mean = 14.728261, loss = 4.03967, prediction/mean = 14.9747305
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5600: tf_wx_model/model.ckpt-5600
# 14
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-5600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5600...
# INFO:tensorflow:Saving checkpoints for 5600 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5600...
# INFO:tensorflow:loss = 4.1276574, step = 5600
# INFO:tensorflow:global_step/sec: 316.504
# INFO:tensorflow:loss = 3.892976, step = 5700 (0.317 sec)
# INFO:tensorflow:global_step/sec: 358.788
# INFO:tensorflow:loss = 3.974727, step = 5800 (0.279 sec)
# INFO:tensorflow:global_step/sec: 354.095
# INFO:tensorflow:loss = 3.8163252, step = 5900 (0.283 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 6000...
# INFO:tensorflow:Saving checkpoints for 6000 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 6000...
# INFO:tensorflow:Loss for final step: 3.540108.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:15:21Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-6000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.19225s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:15:21
# INFO:tensorflow:Saving dict for global step 6000: average_loss = 4.042094, global_step = 6000, label/mean = 14.728261, loss = 4.042094, prediction/mean = 14.984908
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6000: tf_wx_model/model.ckpt-6000
# 15
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-6000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 6000...
# INFO:tensorflow:Saving checkpoints for 6000 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 6000...
# INFO:tensorflow:loss = 3.4726915, step = 6000
# INFO:tensorflow:global_step/sec: 338.414
# INFO:tensorflow:loss = 3.937607, step = 6100 (0.297 sec)
# INFO:tensorflow:global_step/sec: 362.114
# INFO:tensorflow:loss = 3.5203881, step = 6200 (0.276 sec)
# INFO:tensorflow:global_step/sec: 346.612
# INFO:tensorflow:loss = 4.422054, step = 6300 (0.289 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 6400...
# INFO:tensorflow:Saving checkpoints for 6400 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 6400...
# INFO:tensorflow:Loss for final step: 3.938093.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:15:23Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-6400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.19099s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:15:24
# INFO:tensorflow:Saving dict for global step 6400: average_loss = 4.039, global_step = 6400, label/mean = 14.728261, loss = 4.039, prediction/mean = 14.9725275
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6400: tf_wx_model/model.ckpt-6400
# 16
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-6400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 6400...
# INFO:tensorflow:Saving checkpoints for 6400 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 6400...
# INFO:tensorflow:loss = 4.0419755, step = 6400
# INFO:tensorflow:global_step/sec: 324.138
# INFO:tensorflow:loss = 3.6747525, step = 6500 (0.310 sec)
# INFO:tensorflow:global_step/sec: 348.487
# INFO:tensorflow:loss = 4.2262316, step = 6600 (0.287 sec)
# INFO:tensorflow:global_step/sec: 363.394
# INFO:tensorflow:loss = 3.791338, step = 6700 (0.275 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 6800...
# INFO:tensorflow:Saving checkpoints for 6800 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 6800...
# INFO:tensorflow:Loss for final step: 3.7820687.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:15:26Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-6800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.19362s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:15:26
# INFO:tensorflow:Saving dict for global step 6800: average_loss = 4.0420856, global_step = 6800, label/mean = 14.728261, loss = 4.0420856, prediction/mean = 14.978957
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6800: tf_wx_model/model.ckpt-6800
# 17
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-6800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 6800...
# INFO:tensorflow:Saving checkpoints for 6800 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 6800...
# INFO:tensorflow:loss = 3.6217182, step = 6800
# INFO:tensorflow:global_step/sec: 317.997
# INFO:tensorflow:loss = 3.951248, step = 6900 (0.316 sec)
# INFO:tensorflow:global_step/sec: 359.713
# INFO:tensorflow:loss = 3.65034, step = 7000 (0.278 sec)
# INFO:tensorflow:global_step/sec: 355.051
# INFO:tensorflow:loss = 3.442213, step = 7100 (0.282 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 7200...
# INFO:tensorflow:Saving checkpoints for 7200 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 7200...
# INFO:tensorflow:Loss for final step: 4.0715275.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:15:28Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-7200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.18728s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:15:28
# INFO:tensorflow:Saving dict for global step 7200: average_loss = 4.041827, global_step = 7200, label/mean = 14.728261, loss = 4.041827, prediction/mean = 14.9751625
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 7200: tf_wx_model/model.ckpt-7200
# 18
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-7200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 7200...
# INFO:tensorflow:Saving checkpoints for 7200 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 7200...
# INFO:tensorflow:loss = 3.7334795, step = 7200
# INFO:tensorflow:global_step/sec: 311.522
# INFO:tensorflow:loss = 3.8573956, step = 7300 (0.323 sec)
# INFO:tensorflow:global_step/sec: 359.64
# INFO:tensorflow:loss = 3.9424372, step = 7400 (0.278 sec)
# INFO:tensorflow:global_step/sec: 336.217
# INFO:tensorflow:loss = 3.4293542, step = 7500 (0.297 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 7600...
# INFO:tensorflow:Saving checkpoints for 7600 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 7600...
# INFO:tensorflow:Loss for final step: 3.7497125.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:15:30Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-7600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.19010s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:15:31
# INFO:tensorflow:Saving dict for global step 7600: average_loss = 4.044616, global_step = 7600, label/mean = 14.728261, loss = 4.044616, prediction/mean = 14.987273
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 7600: tf_wx_model/model.ckpt-7600
# 19
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-7600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 7600...
# INFO:tensorflow:Saving checkpoints for 7600 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 7600...
# INFO:tensorflow:loss = 4.0759645, step = 7600
# INFO:tensorflow:global_step/sec: 317.259
# INFO:tensorflow:loss = 3.796454, step = 7700 (0.316 sec)
# INFO:tensorflow:global_step/sec: 343.664
# INFO:tensorflow:loss = 3.7173736, step = 7800 (0.291 sec)
# INFO:tensorflow:global_step/sec: 358.287
# INFO:tensorflow:loss = 3.7224567, step = 7900 (0.279 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 8000...
# INFO:tensorflow:Saving checkpoints for 8000 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 8000...
# INFO:tensorflow:Loss for final step: 3.5627718.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:15:33Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-8000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.18702s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:15:33
# INFO:tensorflow:Saving dict for global step 8000: average_loss = 4.0410385, global_step = 8000, label/mean = 14.728261, loss = 4.0410385, prediction/mean = 14.973937
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8000: tf_wx_model/model.ckpt-8000
# 20
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-8000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 8000...
# INFO:tensorflow:Saving checkpoints for 8000 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 8000...
# INFO:tensorflow:loss = 3.681999, step = 8000
# INFO:tensorflow:global_step/sec: 294.909
# INFO:tensorflow:loss = 3.880635, step = 8100 (0.341 sec)
# INFO:tensorflow:global_step/sec: 354.571
# INFO:tensorflow:loss = 3.7219317, step = 8200 (0.282 sec)
# INFO:tensorflow:global_step/sec: 355.755
# INFO:tensorflow:loss = 3.63, step = 8300 (0.281 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 8400...
# INFO:tensorflow:Saving checkpoints for 8400 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 8400...
# INFO:tensorflow:Loss for final step: 3.8243248.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:15:35Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-8400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.18237s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:15:35
# INFO:tensorflow:Saving dict for global step 8400: average_loss = 4.0395994, global_step = 8400, label/mean = 14.728261, loss = 4.0395994, prediction/mean = 14.964681
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8400: tf_wx_model/model.ckpt-8400
# 21
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-8400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 8400...
# INFO:tensorflow:Saving checkpoints for 8400 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 8400...
# INFO:tensorflow:loss = 3.9097047, step = 8400
# INFO:tensorflow:global_step/sec: 298.293
# INFO:tensorflow:loss = 4.31811, step = 8500 (0.337 sec)
# INFO:tensorflow:global_step/sec: 339.957
# INFO:tensorflow:loss = 3.8834426, step = 8600 (0.294 sec)
# INFO:tensorflow:global_step/sec: 352.74
# INFO:tensorflow:loss = 3.7107923, step = 8700 (0.284 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 8800...
# INFO:tensorflow:Saving checkpoints for 8800 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 8800...
# INFO:tensorflow:Loss for final step: 3.8922918.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:15:37Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-8800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.19046s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:15:38
# INFO:tensorflow:Saving dict for global step 8800: average_loss = 4.041825, global_step = 8800, label/mean = 14.728261, loss = 4.041825, prediction/mean = 14.971458
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8800: tf_wx_model/model.ckpt-8800
# 22
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-8800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 8800...
# INFO:tensorflow:Saving checkpoints for 8800 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 8800...
# INFO:tensorflow:loss = 3.621364, step = 8800
# INFO:tensorflow:global_step/sec: 316.133
# INFO:tensorflow:loss = 3.7934146, step = 8900 (0.318 sec)
# INFO:tensorflow:global_step/sec: 355.067
# INFO:tensorflow:loss = 3.477257, step = 9000 (0.282 sec)
# INFO:tensorflow:global_step/sec: 365.942
# INFO:tensorflow:loss = 3.4432256, step = 9100 (0.273 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 9200...
# INFO:tensorflow:Saving checkpoints for 9200 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 9200...
# INFO:tensorflow:Loss for final step: 3.4975185.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:15:40Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-9200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.18780s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:15:40
# INFO:tensorflow:Saving dict for global step 9200: average_loss = 4.049521, global_step = 9200, label/mean = 14.728261, loss = 4.049521, prediction/mean = 14.988668
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9200: tf_wx_model/model.ckpt-9200
# 23
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-9200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 9200...
# INFO:tensorflow:Saving checkpoints for 9200 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 9200...
# INFO:tensorflow:loss = 3.6262693, step = 9200
# INFO:tensorflow:global_step/sec: 316.038
# INFO:tensorflow:loss = 4.1307926, step = 9300 (0.318 sec)
# INFO:tensorflow:global_step/sec: 358.651
# INFO:tensorflow:loss = 3.8519964, step = 9400 (0.279 sec)
# INFO:tensorflow:global_step/sec: 355.98
# INFO:tensorflow:loss = 3.2496057, step = 9500 (0.281 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 9600...
# INFO:tensorflow:Saving checkpoints for 9600 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 9600...
# INFO:tensorflow:Loss for final step: 3.343595.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:15:42Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-9600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.19188s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:15:42
# INFO:tensorflow:Saving dict for global step 9600: average_loss = 4.044001, global_step = 9600, label/mean = 14.728261, loss = 4.044001, prediction/mean = 14.964616
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9600: tf_wx_model/model.ckpt-9600
# 24
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-9600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 9600...
# INFO:tensorflow:Saving checkpoints for 9600 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 9600...
# INFO:tensorflow:loss = 3.664859, step = 9600
# INFO:tensorflow:global_step/sec: 323.383
# INFO:tensorflow:loss = 3.8101373, step = 9700 (0.311 sec)
# INFO:tensorflow:global_step/sec: 334.527
# INFO:tensorflow:loss = 3.93349, step = 9800 (0.299 sec)
# INFO:tensorflow:global_step/sec: 333.884
# INFO:tensorflow:loss = 3.6932461, step = 9900 (0.299 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 10000...
# INFO:tensorflow:Saving checkpoints for 10000 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 10000...
# INFO:tensorflow:Loss for final step: 3.747918.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# ...
# INFO:tensorflow:global_step/sec: 343.271
# INFO:tensorflow:loss = 3.3694599, step = 36700 (0.292 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 36800...
# INFO:tensorflow:Saving checkpoints for 36800 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 36800...
# INFO:tensorflow:Loss for final step: 3.2844565.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:18:18Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-36800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.16988s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:18:19
# INFO:tensorflow:Saving dict for global step 36800: average_loss = 4.009011, global_step = 36800, label/mean = 14.728261, loss = 4.009011, prediction/mean = 14.969919
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 36800: tf_wx_model/model.ckpt-36800
# 92
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-36800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 36800...
# INFO:tensorflow:Saving checkpoints for 36800 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 36800...
# INFO:tensorflow:loss = 3.667817, step = 36800
# INFO:tensorflow:global_step/sec: 294.231
# INFO:tensorflow:loss = 3.7095966, step = 36900 (0.341 sec)
# INFO:tensorflow:global_step/sec: 362.792
# INFO:tensorflow:loss = 3.6516426, step = 37000 (0.276 sec)
# INFO:tensorflow:global_step/sec: 293.057
# INFO:tensorflow:loss = 3.587657, step = 37100 (0.341 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 37200...
# INFO:tensorflow:Saving checkpoints for 37200 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 37200...
# INFO:tensorflow:Loss for final step: 4.1031704.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:18:21Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-37200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.16934s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:18:21
# INFO:tensorflow:Saving dict for global step 37200: average_loss = 4.007295, global_step = 37200, label/mean = 14.728261, loss = 4.007295, prediction/mean = 14.967028
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 37200: tf_wx_model/model.ckpt-37200
# 93
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-37200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 37200...
# INFO:tensorflow:Saving checkpoints for 37200 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 37200...
# INFO:tensorflow:loss = 3.6960387, step = 37200
# INFO:tensorflow:global_step/sec: 314.052
# INFO:tensorflow:loss = 3.3778589, step = 37300 (0.320 sec)
# INFO:tensorflow:global_step/sec: 350.951
# INFO:tensorflow:loss = 3.6733637, step = 37400 (0.285 sec)
# INFO:tensorflow:global_step/sec: 348.045
# INFO:tensorflow:loss = 3.5877707, step = 37500 (0.287 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 37600...
# INFO:tensorflow:Saving checkpoints for 37600 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 37600...
# INFO:tensorflow:Loss for final step: 3.2956147.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:18:23Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-37600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.17268s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:18:23
# INFO:tensorflow:Saving dict for global step 37600: average_loss = 4.0066385, global_step = 37600, label/mean = 14.728261, loss = 4.0066385, prediction/mean = 14.967302
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 37600: tf_wx_model/model.ckpt-37600
# 94
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-37600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 37600...
# INFO:tensorflow:Saving checkpoints for 37600 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 37600...
# INFO:tensorflow:loss = 3.354561, step = 37600
# INFO:tensorflow:global_step/sec: 266.162
# INFO:tensorflow:loss = 3.2449224, step = 37700 (0.376 sec)
# INFO:tensorflow:global_step/sec: 362.202
# INFO:tensorflow:loss = 3.6434727, step = 37800 (0.277 sec)
# INFO:tensorflow:global_step/sec: 347.973
# INFO:tensorflow:loss = 3.548404, step = 37900 (0.287 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 38000...
# INFO:tensorflow:Saving checkpoints for 38000 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 38000...
# INFO:tensorflow:Loss for final step: 3.445359.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:18:25Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-38000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.18551s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:18:25
# INFO:tensorflow:Saving dict for global step 38000: average_loss = 4.0068803, global_step = 38000, label/mean = 14.728261, loss = 4.0068803, prediction/mean = 14.968993
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 38000: tf_wx_model/model.ckpt-38000
# 95
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-38000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 38000...
# INFO:tensorflow:Saving checkpoints for 38000 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 38000...
# INFO:tensorflow:loss = 3.399098, step = 38000
# INFO:tensorflow:global_step/sec: 303.217
# INFO:tensorflow:loss = 3.6564944, step = 38100 (0.331 sec)
# INFO:tensorflow:global_step/sec: 325.302
# INFO:tensorflow:loss = 3.923183, step = 38200 (0.307 sec)
# INFO:tensorflow:global_step/sec: 360.189
# INFO:tensorflow:loss = 3.690635, step = 38300 (0.278 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 38400...
# INFO:tensorflow:Saving checkpoints for 38400 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 38400...
# INFO:tensorflow:Loss for final step: 3.597083.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:18:28Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-38400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.18657s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:18:28
# INFO:tensorflow:Saving dict for global step 38400: average_loss = 4.0067067, global_step = 38400, label/mean = 14.728261, loss = 4.0067067, prediction/mean = 14.968627
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 38400: tf_wx_model/model.ckpt-38400
# 96
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-38400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 38400...
# INFO:tensorflow:Saving checkpoints for 38400 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 38400...
# INFO:tensorflow:loss = 3.5816772, step = 38400
# INFO:tensorflow:global_step/sec: 320.602
# INFO:tensorflow:loss = 3.6310303, step = 38500 (0.313 sec)
# INFO:tensorflow:global_step/sec: 365.702
# INFO:tensorflow:loss = 3.7043033, step = 38600 (0.273 sec)
# INFO:tensorflow:global_step/sec: 337.937
# INFO:tensorflow:loss = 3.7169564, step = 38700 (0.296 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 38800...
# INFO:tensorflow:Saving checkpoints for 38800 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 38800...
# INFO:tensorflow:Loss for final step: 3.9442358.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:18:30Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-38800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.18842s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:18:30
# INFO:tensorflow:Saving dict for global step 38800: average_loss = 4.0060706, global_step = 38800, label/mean = 14.728261, loss = 4.0060706, prediction/mean = 14.9669485
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 38800: tf_wx_model/model.ckpt-38800
# 97
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-38800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 38800...
# INFO:tensorflow:Saving checkpoints for 38800 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 38800...
# INFO:tensorflow:loss = 3.5071862, step = 38800
# INFO:tensorflow:global_step/sec: 308.242
# INFO:tensorflow:loss = 3.6362066, step = 38900 (0.326 sec)
# INFO:tensorflow:global_step/sec: 362.131
# INFO:tensorflow:loss = 3.4586303, step = 39000 (0.276 sec)
# INFO:tensorflow:global_step/sec: 359.366
# INFO:tensorflow:loss = 3.5672898, step = 39100 (0.278 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 39200...
# INFO:tensorflow:Saving checkpoints for 39200 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 39200...
# INFO:tensorflow:Loss for final step: 3.952578.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:18:32Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-39200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.18626s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:18:32
# INFO:tensorflow:Saving dict for global step 39200: average_loss = 4.005875, global_step = 39200, label/mean = 14.728261, loss = 4.005875, prediction/mean = 14.966759
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 39200: tf_wx_model/model.ckpt-39200
# 98
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-39200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 39200...
# INFO:tensorflow:Saving checkpoints for 39200 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 39200...
# INFO:tensorflow:loss = 3.479444, step = 39200
# INFO:tensorflow:global_step/sec: 297.911
# INFO:tensorflow:loss = 3.3541937, step = 39300 (0.337 sec)
# INFO:tensorflow:global_step/sec: 353.914
# INFO:tensorflow:loss = 3.5377831, step = 39400 (0.283 sec)
# INFO:tensorflow:global_step/sec: 351.595
# INFO:tensorflow:loss = 3.9390435, step = 39500 (0.284 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 39600...
# INFO:tensorflow:Saving checkpoints for 39600 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 39600...
# INFO:tensorflow:Loss for final step: 3.2515914.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:18:35Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-39600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.18892s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:18:35
# INFO:tensorflow:Saving dict for global step 39600: average_loss = 4.00742, global_step = 39600, label/mean = 14.728261, loss = 4.00742, prediction/mean = 14.974478
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 39600: tf_wx_model/model.ckpt-39600
# 99
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-39600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 39600...
# INFO:tensorflow:Saving checkpoints for 39600 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 39600...
# INFO:tensorflow:loss = 3.5926147, step = 39600
# INFO:tensorflow:global_step/sec: 318.383
# INFO:tensorflow:loss = 3.656411, step = 39700 (0.316 sec)
# INFO:tensorflow:global_step/sec: 362.025
# INFO:tensorflow:loss = 3.6084008, step = 39800 (0.276 sec)
# INFO:tensorflow:global_step/sec: 331.02
# INFO:tensorflow:loss = 3.4449646, step = 39900 (0.302 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 40000...
# INFO:tensorflow:Saving checkpoints for 40000 into tf_wx_model/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 40000...
# INFO:tensorflow:Loss for final step: 3.1661901.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-21T22:18:37Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-40000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.18892s
# INFO:tensorflow:Finished evaluation at 2021-05-21-22:18:37
# INFO:tensorflow:Saving dict for global step 40000: average_loss = 4.006461, global_step = 40000, label/mean = 14.728261, loss = 4.006461, prediction/mean = 14.972711
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 40000: tf_wx_model/model.ckpt-40000

# %% [markdown]
# #### Para explicar porque ejecuto `evaluate(...)` en cada ejecucion del bucle y almaceno su resultado en una lista, voy a explicar que ocurre cuando se ejecuta `train(...)`
# #### Este metodo selecciona un lote aleatorio de datos y lo introduce en la red hasta que se hace la prediccion, y para cada registro se calcula la funcion de perdida (loss function)
# #### Despues, a partir del calculo de la funcion de perdida, los pesos son ajustados de acuerdo a lo que diga la logica del optimizador, que busca hacer ajustes de modo que se reduzca la perdida total en la siguiente iteracion
# #### Los valores de perdida por lo general, van disminuyendo con las iteraciones, pero hay un cierto punto donde la red puede verse influida por ruido heredado de los datos y deja de ser valida para futuras predicciones
# #### Por eso mismo almaceno el valor de cada evaluacion en una lista, para a continuacion realizar una grafica con los valores de perdida. De este modo podre vigilar que la red no lega a ese punto donde ya no nos seria util. Cuando la red llega a este punto, se dice que esta overfitted

# %% [markdown]
# #### Realizo una grafica que muestre como va evolucionando la funcion de loss con las iteraciones

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# manually set the parameters of the figure to and appropriate size
plt.rcParams['figure.figsize'] = [14, 10]

loss_values = [ev['loss'] for ev in evaluations]
training_steps = [ev['global_step'] for ev in evaluations]

plt.scatter(x=training_steps, y=loss_values)
plt.xlabel('Training steps (Epochs = steps / 2)')
plt.ylabel('Loss (SSE)')
plt.show()

# %% [markdown]
# #### Como podemos observar, la red no llega a estar overfitted, el valor se estabiliza entre 4.0 y 4.5 así que las oscilaciones no son demasiado determinantes
#
# #### A continuacion voy a hacer la prediccion y a comparar la desviacion de los valores obtenidos respecto a los que deberia obtener

# %%
# hago una prediccion usando el dataset de test
pred = regressor.predict(input_fn=wx_input_fn(X_test,
                                              num_epochs=1,
                                              shuffle=False))

predictions = np.array([p['predictions'][0] for p in pred])

# Evaluo la exactitud de la prediccion
print("Variacion explicada: %.2f" % explained_variance_score(
                                            y_test, predictions))  
print("Error absoluto medio %.2f grados centigados" % mean_absolute_error(
                                            y_test, predictions))  
print("Desviación media absoluta: %.2f grados centigrados" % median_absolute_error(
                                            y_test, predictions))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model/model.ckpt-40000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Variacion explicada: 0.95
# Error absoluto medio 1.47 grados centigados
# Desviación media absoluta: 1.19 grados centigrados

# %% [markdown]
# - La variación explicada mide la proporción en la que un modelo matemático explica la variación ( dispersión ) de un conjunto de datos dado
# - El error absoluto medio es una medida de la diferencia entre dos variables continuas. Considerando dos series de datos (unos calculados y otros observados) relativos a un mismo fenómeno, el error absoluto medio sirve para cuantificar la precisión de una técnica de predicción comparando por ejemplo los valores predichos frente a los observados, el tiempo real frente al tiempo previsto, o una técnica de medición frente a otra técnica alternativa de medición.
# - La desviación media absoluta de un conjunto de datos es la distancia promedio entre cada valor y el promedio. La desviación media absoluta es una manera de describir la variación en un conjunto de datos. La desviación media absoluta nos ayuda a tener una idea de qué tan "extendidos" están los valores en un conjunto de datos.

# %% [markdown]
# #### Hemos obtenido algo de mejora respecto a la regresion lineal, cuya varianza era de 0.93

# %% [markdown]
# #### La conclusion que he obtenido de este proyecto, es que no existe un modelo optimo. Cada dataSet es unico y se debe buscar el modelo mas optimo a base de prueba y error.
# #### Actualmente tenemos la ventaja de contar con librerias como esta de TensorFLow que son muy potentes y muy faciles de usar, lo que permite cambiar de modelo rapidamente
